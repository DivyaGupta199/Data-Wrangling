# %%
import pandas as pd

# %%
df = pd.read_csv(r"IPL Auction Dataset.csv")

# %%
df.head(10)
# Out:
#    Sl.No       Country                Player                         Team  \
# 0      0        Guyana  Christopher Barnwell  Royal Challengers Bangalore
# 1      1  South Africa           Johan Botha             Delhi Daredevils
# 2      2     Australia      Daniel Christian  Royal Challengers Bangalore
# 3      3     Australia        Michael Clarke          Pune Warriors India
# 4      4     Australia   Nathan Coulter-Nile               Mumbai Indians
# 5      5     Sri Lanka       Akila Dananjaya          Chennai Super Kings
# 6      6  South Africa       Quinton de Kock          Sunrisers Hyderabad
# 7      7      Barbados         Fidel Edwards             Rajasthan Royals
# 8      8     Australia        James Faulkner             Rajasthan Royals
# 9      9         India         Manpreet Gony              Kings XI Punjab
#
#    Base price Winning bid  Year
# 0        30.5        30.5  2013
# 1       183.0       274.5  2013
# 2        61.0          61  2013
# ...

# %%
df.shape
# Out:
# (1052, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sl.No        1052 non-null   int64
#  1   Country      1052 non-null   object
#  2   Player       1052 non-null   object
#  3   Team         1052 non-null   object
#  4   Base price   1052 non-null   float64
#  5   Winning bid  1052 non-null   object
#  6   Year         1052 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 57.7+ KB

# %%
df.dtypes
# Out:
# Sl.No            int64
# Country         object
# Player          object
# Team            object
# Base price     float64
# Winning bid     object
# Year             int64
# dtype: object

# %%
index = df['Sl.No']

# %%
df = df.reindex(index)

# %%
df
# Out:
#        Sl.No       Country                Player                         Team  \
# Sl.No
# 0          0        Guyana  Christopher Barnwell  Royal Challengers Bangalore
# 1          1  South Africa           Johan Botha             Delhi Daredevils
# 2          2     Australia      Daniel Christian  Royal Challengers Bangalore
# 3          3     Australia        Michael Clarke          Pune Warriors India
# 4          4     Australia   Nathan Coulter-Nile               Mumbai Indians
# ...      ...           ...                   ...                          ...
# 1047    1047       England              Joe Root             Rajasthan Royals
# 1048    1048    Bangladesh       Shakib al Hasan        Kolkata Knight Riders
# 1049    1049         India          Abdul Basith             Rajasthan Royals
# 1050    1050       England              Joe Root             Rajasthan Royals
# 1051    1051    Bangladesh       Shakib al Hasan        Kolkata Knight Riders
#
# ...

# %%
df = df.drop(['Sl.No'], axis = 1)

# %%
df
# Out:
#             Country                Player                         Team  \
# Sl.No
# 0            Guyana  Christopher Barnwell  Royal Challengers Bangalore
# 1      South Africa           Johan Botha             Delhi Daredevils
# 2         Australia      Daniel Christian  Royal Challengers Bangalore
# 3         Australia        Michael Clarke          Pune Warriors India
# 4         Australia   Nathan Coulter-Nile               Mumbai Indians
# ...             ...                   ...                          ...
# 1047        England              Joe Root             Rajasthan Royals
# 1048     Bangladesh       Shakib al Hasan        Kolkata Knight Riders
# 1049          India          Abdul Basith             Rajasthan Royals
# 1050        England              Joe Root             Rajasthan Royals
# 1051     Bangladesh       Shakib al Hasan        Kolkata Knight Riders
#
#        Base price Winning bid  Year
# Sl.No
# 0            30.5        30.5  2013
# ...

# %%
df['Year'] = '10-05-2023'

# %%
df
# Out:
#             Country                Player                         Team  \
# Sl.No
# 0            Guyana  Christopher Barnwell  Royal Challengers Bangalore
# 1      South Africa           Johan Botha             Delhi Daredevils
# 2         Australia      Daniel Christian  Royal Challengers Bangalore
# 3         Australia        Michael Clarke          Pune Warriors India
# 4         Australia   Nathan Coulter-Nile               Mumbai Indians
# ...             ...                   ...                          ...
# 1047        England              Joe Root             Rajasthan Royals
# 1048     Bangladesh       Shakib al Hasan        Kolkata Knight Riders
# 1049          India          Abdul Basith             Rajasthan Royals
# 1050        England              Joe Root             Rajasthan Royals
# 1051     Bangladesh       Shakib al Hasan        Kolkata Knight Riders
#
#        Base price Winning bid        Year
# Sl.No
# 0            30.5        30.5  10-05-2023
# ...

# %%
df.dtypes
# Out:
# Country         object
# Player          object
# Team            object
# Base price     float64
# Winning bid     object
# Year            object
# dtype: object

# %%
df['Year'] = pd.to_datetime(df['Year'])

# %%
df
# Out:
#             Country                Player                         Team  \
# Sl.No
# 0            Guyana  Christopher Barnwell  Royal Challengers Bangalore
# 1      South Africa           Johan Botha             Delhi Daredevils
# 2         Australia      Daniel Christian  Royal Challengers Bangalore
# 3         Australia        Michael Clarke          Pune Warriors India
# 4         Australia   Nathan Coulter-Nile               Mumbai Indians
# ...             ...                   ...                          ...
# 1047        England              Joe Root             Rajasthan Royals
# 1048     Bangladesh       Shakib al Hasan        Kolkata Knight Riders
# 1049          India          Abdul Basith             Rajasthan Royals
# 1050        England              Joe Root             Rajasthan Royals
# 1051     Bangladesh       Shakib al Hasan        Kolkata Knight Riders
#
#        Base price Winning bid       Year
# Sl.No
# 0            30.5        30.5 2023-10-05
# ...

# %%
df.rename(columns={'Year' : 'Date'})
# Out:
#             Country                Player                         Team  \
# Sl.No
# 0            Guyana  Christopher Barnwell  Royal Challengers Bangalore
# 1      South Africa           Johan Botha             Delhi Daredevils
# 2         Australia      Daniel Christian  Royal Challengers Bangalore
# 3         Australia        Michael Clarke          Pune Warriors India
# 4         Australia   Nathan Coulter-Nile               Mumbai Indians
# ...             ...                   ...                          ...
# 1047        England              Joe Root             Rajasthan Royals
# 1048     Bangladesh       Shakib al Hasan        Kolkata Knight Riders
# 1049          India          Abdul Basith             Rajasthan Royals
# 1050        England              Joe Root             Rajasthan Royals
# 1051     Bangladesh       Shakib al Hasan        Kolkata Knight Riders
#
#        Base price Winning bid       Date
# Sl.No
# 0            30.5        30.5 2023-10-05
# ...

# %%
df1 = df.duplicated()

# %%
df1
# Out:
# Sl.No
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1047    False
# 1048    False
# 1049     True
# 1050     True
# 1051     True
# Length: 1052, dtype: bool

# %%
df1 = df.drop_duplicates()

# %%
df1.duplicated(['Player'])
# Out:
# Sl.No
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1044     True
# 1045     True
# 1046     True
# 1047     True
# 1048     True
# Length: 1040, dtype: bool

# %%
1. get the dataset
2. info
3. check for null values and duplicates
4. treat the null values
5. drop the duplicate records
6. make the dtype correct for all the features

# %%
df.isnull().sum()
# Out:
# Country        0
# Player         0
# Team           0
# Base price     0
# Winning bid    0
# Year           0
# dtype: int64
